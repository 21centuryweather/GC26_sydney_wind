# %%
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %%
#Path g/data/gb02/mjl561
ds_u_win_DJF_11km_CTRL = xr.open_dataset('/g/data/gb02/mjl561/um2nc/SY_djf/SY_11p1/CTRL/wnd_ucmp-SY_SY_11p1_CTRL-v1-201611300100-201703010000.nc')
ds_u_win_DJF_11km_CTRL
# Out:
# /jobfs/171321357.gadi-pbs/ipykernel_2967058/2149263326.py:2: FutureWarning: In a future version, xarray will not decode the variable 'forecast_period' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds_u_win_DJF_11km_CTRL = xr.open_dataset('/g/data/gb02/mjl561/um2nc/SY_djf/SY_11p1/CTRL/wnd_ucmp-SY_SY_11p1_CTRL-v1-201611300100-201703010000.nc')
# <xarray.Dataset> Size: 9GB
# Dimensions:                  (time: 2184, model_level_number: 8, latitude: 320,
#                               longitude: 400)
# Coordinates:
# ...

# %%
u_win_DJF_11km_CTRL = ds_u_win_DJF_11km_CTRL['wnd_ucmp']
u_win_DJF_11km_CTRL
# Out:
# <xarray.DataArray 'wnd_ucmp' (time: 2184, model_level_number: 8, latitude: 320,
#                               longitude: 400)> Size: 9GB
# [2236416000 values with dtype=float32]
# Coordinates:
#   * time                     (time) datetime64[ns] 17kB 2016-11-30T01:00:00 ....
#     forecast_period          (time) timedelta64[ns] 17kB ...
#   * model_level_number       (model_level_number) int64 64B 1 2 3 4 5 6 7 8
#     level_height             (model_level_number) float64 64B ...
#     sigma                    (model_level_number) float64 64B ...
#   * latitude                 (latitude) float64 3kB -51.48 -51.37 ... -16.39
#   * longitude                (longitude) float64 3kB 129.1 129.2 ... 172.9 173.0
#     forecast_reference_time  datetime64[ns] 8B ...
# Attributes: (12/14)
#     standard_name:          x_wind
#     units:                  m s-1
#     STASH:                  [1 0 2]
#     bom_name:               wnd_ucmp
# ...

# %%
#import level_height from ds_u_win_DJF_1km_CTRL
level_height = ds_u_win_DJF_11km_CTRL['level_height']
level_height
# Out:
# <xarray.DataArray 'level_height' (model_level_number: 8)> Size: 64B
# [8 values with dtype=float64]
# Coordinates:
#   * model_level_number       (model_level_number) int64 64B 1 2 3 4 5 6 7 8
#     level_height             (model_level_number) float64 64B ...
#     sigma                    (model_level_number) float64 64B ...
#     forecast_reference_time  datetime64[ns] 8B ...
# Attributes:
#     long_name:  level_height
#     units:      m
#     positive:   up

# %%
print(level_height.values)
# Out:
# [ 10.     36.664  76.664 130.    196.664 276.664 370.    476.664]

# %%
#Path g/data/gb02/mjl561
ds_v_win_DJF_11km_CTRL = xr.open_dataset('/g/data/gb02/mjl561/um2nc/SY_djf/SY_11p1/CTRL/wnd_vcmp-SY_SY_11p1_CTRL-v1-201611300100-201703010000.nc')
ds_v_win_DJF_11km_CTRL
# Out:
# /jobfs/171321357.gadi-pbs/ipykernel_2967058/1487733526.py:2: FutureWarning: In a future version, xarray will not decode the variable 'forecast_period' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds_v_win_DJF_11km_CTRL = xr.open_dataset('/g/data/gb02/mjl561/um2nc/SY_djf/SY_11p1/CTRL/wnd_vcmp-SY_SY_11p1_CTRL-v1-201611300100-201703010000.nc')
# <xarray.Dataset> Size: 9GB
# Dimensions:                  (time: 2184, model_level_number: 8, latitude: 321,
#                               longitude: 400)
# Coordinates:
# ...

# %%
v_win_DJF_11km_CTRL = ds_v_win_DJF_11km_CTRL['wnd_vcmp']
v_win_DJF_11km_CTRL
# Out:
# <xarray.DataArray 'wnd_vcmp' (time: 2184, model_level_number: 8, latitude: 321,
#                               longitude: 400)> Size: 9GB
# [2243404800 values with dtype=float32]
# Coordinates:
#   * time                     (time) datetime64[ns] 17kB 2016-11-30T01:00:00 ....
#     forecast_period          (time) timedelta64[ns] 17kB ...
#   * model_level_number       (model_level_number) int64 64B 1 2 3 4 5 6 7 8
#     level_height             (model_level_number) float64 64B ...
#     sigma                    (model_level_number) float64 64B ...
#   * latitude                 (latitude) float64 3kB -51.53 -51.42 ... -16.33
#   * longitude                (longitude) float64 3kB 129.2 129.3 ... 173.0 173.1
#     forecast_reference_time  datetime64[ns] 8B ...
# Attributes: (12/14)
#     standard_name:          y_wind
#     units:                  m s-1
#     STASH:                  [1 0 3]
#     bom_name:               wnd_vcmp
# ...

# %%
level_height2 = ds_v_win_DJF_11km_CTRL['level_height']
level_height2
# Out:
# <xarray.DataArray 'level_height' (model_level_number: 8)> Size: 64B
# [8 values with dtype=float64]
# Coordinates:
#   * model_level_number       (model_level_number) int64 64B 1 2 3 4 5 6 7 8
#     level_height             (model_level_number) float64 64B ...
#     sigma                    (model_level_number) float64 64B ...
#     forecast_reference_time  datetime64[ns] 8B ...
# Attributes:
#     long_name:  level_height
#     units:      m
#     positive:   up

# %%
print(level_height2.values)
# Out:
# [ 10.     36.664  76.664 130.    196.664 276.664 370.    476.664]

# %%
#Calculating wind speed 
u_wind = u_win_DJF_11km_CTRL
v_wind = v_win_DJF_11km_CTRL
wind_speed = np.sqrt(u_wind**2+v_wind**2)
print (wind_speed)
# Out:
# <xarray.DataArray (time: 2184, model_level_number: 8, latitude: 0, longitude: 0)> Size: 0B
# array([], shape=(2184, 8, 0, 0), dtype=float32)
# Coordinates:
#   * time                     (time) datetime64[ns] 17kB 2016-11-30T01:00:00 ....
#     forecast_period          (time) timedelta64[ns] 17kB 01:00:00 ... 1 days ...
#   * model_level_number       (model_level_number) int64 64B 1 2 3 4 5 6 7 8
#     level_height             (model_level_number) float64 64B 10.0 ... 476.7
#     sigma                    (model_level_number) float64 64B 0.9989 ... 0.9464
#   * latitude                 (latitude) float64 0B
#   * longitude                (longitude) float64 0B
#     forecast_reference_time  datetime64[ns] 8B 2016-11-30
# Attributes:
#     units:                  m s-1
#     land_sea:               both
#     coverage_content_type:  modelResult

# %%
# --- Calculate time mean ---
wind_speed_mean = wind_speed.mean(dim='time')

# --- Plot ---
fig, ax = plt.subplots(
    figsize=(10, 8),
    subplot_kw={'projection': ccrs.PlateCarree()}
)

# Plot wind speed
im = ax.pcolormesh(
    wind_speed_mean.longitude,
    wind_speed_mean.latitude,
    wind_speed_mean,
    cmap='YlOrRd',
    transform=ccrs.PlateCarree()
)

# Add map features
ax.add_feature(cfeature.COASTLINE, linewidth=0.8)
ax.add_feature(cfeature.BORDERS, linewidth=0.5)
ax.add_feature(cfeature.STATES, linewidth=0.5, linestyle='--')

# Colorbar
cbar = plt.colorbar(im, ax=ax, orientation='vertical', pad=0.02, shrink=0.8)
cbar.set_label('Wind Speed (m/s)', fontsize=12)

# Labels and title
ax.set_title('Mean 10m Wind Speed — DJF CTRL (1km)', fontsize=14, fontweight='bold')
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
ax.gridlines(draw_labels=True, linewidth=0.3, color='gray', alpha=0.5)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 11
#       7     subplot_kw={'projection': ccrs.PlateCarree()}
#       8 )
#       9
#      10 # Plot wind speed
# ---> 11 im = ax.pcolormesh(
#      12     wind_speed_mean.longitude,
#      13     wind_speed_mean.latitude,
#      14     wind_speed_mean,
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-26.05/lib/python3.12/site-packages/cartopy/mpl/geoaxes.py:291, in _add_transform.<locals>.wrapper(self, *args, **kwargs)
#     286     raise ValueError(f'Invalid transform: Spherical {func.__name__} '
#     287                      'is not supported - consider using '
#     288                      'PlateCarree/RotatedPole.')
#     290 kwargs['transform'] = transform
# --> 291 return func(self, *args, **kwargs)
#
# ...
